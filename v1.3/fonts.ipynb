# %%
import os

# These are the font paths from your image_translator.py file
# Now including the new unicode_fallback
font_paths = {
    'default': "/usr/share/fonts/truetype/dejavu/DejaVuSans.ttf",
    'bold': "/usr/share/fonts/truetype/dejavu/DejaVuSans-Bold.ttf",
    'fallback': "/usr/share/fonts/truetype/liberation/LiberationSans-Regular.ttf",
    'unicode_fallback': "/usr/share/fonts/opentype/noto/NotoSansCJK-Regular.ttc" # <--- This is the new line
}

print("--- Checking Font Paths in Codespaces ---")
for font_type, path in font_paths.items():
    if os.path.exists(path):
        print(f"✅ {font_type.capitalize()} font found at: {path}")
    else:
        print(f"❌ {font_type.capitalize()} font NOT found at: {path}")
        print(f"   (File does not exist or path is incorrect)")

print("---------------------------------------")
# Out:
# --- Checking Font Paths in Codespaces ---
# ✅ Default font found at: /usr/share/fonts/truetype/dejavu/DejaVuSans.ttf
# ✅ Bold font found at: /usr/share/fonts/truetype/dejavu/DejaVuSans-Bold.ttf
# ✅ Fallback font found at: /usr/share/fonts/truetype/liberation/LiberationSans-Regular.ttf
# ✅ Unicode_fallback font found at: /usr/share/fonts/opentype/noto/NotoSansCJK-Regular.ttc
# ---------------------------------------
